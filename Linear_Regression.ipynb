# %%
# If you do not use colab. You should install these packages.
# !pip install numpy
# !pip install pandas
# !pip install matplotlib
# !pip install scikit-learn
# !pip install graphviz
# Out:
# Requirement already satisfied: numpy in c:\users\janas\anaconda3\lib\site-packages (1.26.4)
# Requirement already satisfied: pandas in c:\users\janas\anaconda3\lib\site-packages (2.2.2)
# Requirement already satisfied: numpy>=1.26.0 in c:\users\janas\anaconda3\lib\site-packages (from pandas) (1.26.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\janas\anaconda3\lib\site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\janas\anaconda3\lib\site-packages (from pandas) (2024.1)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\janas\anaconda3\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\janas\anaconda3\lib\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# Requirement already satisfied: matplotlib in c:\users\janas\anaconda3\lib\site-packages (3.8.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\janas\anaconda3\lib\site-packages (from matplotlib) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\janas\anaconda3\lib\site-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\janas\anaconda3\lib\site-packages (from matplotlib) (4.51.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\janas\anaconda3\lib\site-packages (from matplotlib) (1.4.4)
# Requirement already satisfied: numpy>=1.21 in c:\users\janas\anaconda3\lib\site-packages (from matplotlib) (1.26.4)
# Requirement already satisfied: packaging>=20.0 in c:\users\janas\anaconda3\lib\site-packages (from matplotlib) (23.2)
# Requirement already satisfied: pillow>=8 in c:\users\janas\anaconda3\lib\site-packages (from matplotlib) (10.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\janas\anaconda3\lib\site-packages (from matplotlib) (3.0.9)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\janas\anaconda3\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in c:\users\janas\anaconda3\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: scikit-learn in c:\users\janas\anaconda3\lib\site-packages (1.4.2)
# Requirement already satisfied: numpy>=1.19.5 in c:\users\janas\anaconda3\lib\site-packages (from scikit-learn) (1.26.4)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\janas\anaconda3\lib\site-packages (from scikit-learn) (1.13.1)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\janas\anaconda3\lib\site-packages (from scikit-learn) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in c:\users\janas\anaconda3\lib\site-packages (from scikit-learn) (2.2.0)
# Collecting graphviz
#   Using cached graphviz-0.21-py3-none-any.whl.metadata (12 kB)
# Using cached graphviz-0.21-py3-none-any.whl (47 kB)
# Installing collected packages: graphviz
# Successfully installed graphviz-0.21

# %%
# %matplotlib inline
# %reload_ext autoreload
# %autoreload 2

# %%
from model.metrics import MSE, MAE, evaluate_linear_regression
from model.gradients import MSE_grad, MAE_grad
from model.utils import *
import matplotlib.pyplot as plt
# Out:
# ---------------------------------------------------------------------------
# ImportError                               Traceback (most recent call last)
# Cell In[14], line 2
#       1 from model.metrics import MSE, MAE, evaluate_linear_regression
# ----> 2 from model.gradients import MSE_grad, MAE_grad
#       3 from model.utils import *
#       4 import matplotlib.pyplot as plt
#
# ImportError: cannot import name 'MAE_grad' from 'model.gradients' (c:\Users\janas\OneDrive - Universität Mannheim\GoodNotes2\4. Semester\Data Mining\Assignemt1\DataMining_Assignment1\model\gradients.py)

# %%
# Sample Code for generating datasets
seed=42
np.random.seed(seed)
size = 500
dim = 1
noise_bound = 0.2
X,y,W = generate_linear_dataset(size,dim,noise_bound=noise_bound,is_reg=True)
plt.scatter(X[:,1],y)

# %%
# Loading data
loaded_data = np.load(f'data/linear_data/linear_data_D.npz')

X = loaded_data['X_data']
y = loaded_data['y_data']
W = loaded_data['W_data']

# Show the size of data
print(f"X size : {X.shape}, y size : {y.shape}")

# Make sure size and dim correct.
size = X.shape[0]
dim = X.shape[1]-1
# Out:
# X size : (8000, 6), y size : (8000,)

# %%
# Train the model
from model.linear_model import LinearModel

seed = 42 # do not change the seed
np.random.seed(seed)

# Setting loss function and gradient. 
loss_fn = MSE
grad_fn = MSE_grad

# Split dataset to train dataset and validation dataset
X_train,y_train,X_val,y_val = get_train_val(X,y)

# Setting model and starting training
model = LinearModel(dim,True,loss_fn,grad_fn)
model.fit(X_train,y_train,lr=0.001,n_iteration =500,val_ratio=0.2)
# Out:
# 50. Training loss: 1.7684511643778449, Val loss:1.7808955296769526
# 100. Training loss: 1.464852496414385, Val loss:1.4770554865390984
# 150. Training loss: 1.2159645145907354, Val loss:1.2278106296911493
# 200. Training loss: 1.0119199428934709, Val loss:1.0233353741451867
# 250. Training loss: 0.8446325767970521, Val loss:0.8555746535033422
# 300. Training loss: 0.7074755244845351, Val loss:0.71792454665939
# 350. Training loss: 0.5950176249327076, Val loss:0.6049705693586137
# 400. Training loss: 0.5028075148402401, Val loss:0.5122732093945561
# 450. Training loss: 0.42719672326568947, Val loss:0.43619216922708653
# 500. Training loss: 0.3651947340371162, Val loss:0.3737423235472047

# %%
# Get the Prediction
y_val_pred = model.predict(X_val)

# %%
# Evaluation 
# Please complete the evaluate_linear_regression in the model/metrics.py by the sklearn package.
evaluate_linear_regression(y_true=y_val,y_pred=y_val_pred,title='Linear Regression Evaluation')
# Out:
# === Linear Regression Evaluation ===
# MSE       : 0.3540
# MAE       : 0.4778
# RMSE      : 0.5950
# R-squared : 0.8780
# {'MSE': 0.35401418955181013,
#  'MAE': 0.4777943162702677,
#  'RMSE': 0.5949909155204054,
#  'R-squared': 0.8779984326846808}

# %%
# Plot
plt.scatter(X_val[:,1],y_val)
plt.plot(X_val[:,1],y_val_pred)
plt.show()
